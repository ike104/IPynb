# %%
import numpy as np
import pylab as plt


x = np.arange(-100,100,0.1)
y = np.cos(x)
plt.plot(x,y)

# %% [markdown]
# #見出し
#
# 本文
#
# 段落、*ここを強調*
# 段落
#
# 段落１
#
# 段落２
#
# - 箇条書き
# - 箇条書き３
#
# ##見出し２
